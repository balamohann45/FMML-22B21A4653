# %% [markdown]
# <a href="https://colab.research.google.com/github/balamohann45/FMML-22B21A4653/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 14:44:35--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   206MB/s    in 0.3s
#
# 2024-03-28 14:44:36 (206 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 35314  cs/0312038v1  Causality is typically treated an all-or-nothi...    cs
# 7330   1711.10168v2  With the rapid increase of compound databases ...  stat
# 12269  1711.00905v1  A major challenge in X-ray computed tomography...  stat
# 23497   1301.3560v1  This paper describes serial and parallel compo...    cs
# 9945    1412.1138v1  A database of fetal heart rate (FHR) time seri...    cs
# ...             ...                                                ...   ...
# 22892  1710.02264v1  Reducing user attrition, i.e. churn, is a broa...  stat
# 25782  1511.06654v2  In this paper, we present a novel method based...    cs
# 21621   1203.1828v1  We present an alternating augmented Lagrangian...  stat
# 10371   1301.6314v2  A measure of dependence is said to be equitabl...    cs
# 38148   1206.4958v1  The Chinese language poses challenges for natu...    cs
#
#                                                    title  year  \
# 35314  Responsibility and blame: a structural-model a...  2003
# 7330   Semi-supervised learning of hierarchical repre...  2017
# 12269  Sparse-View X-Ray CT Reconstruction Using $\el...  2017
# 23497  Complexity of Representation and Inference in ...  2013
# 9945        Highly comparative fetal heart rate analysis  2014
# ...                                                  ...   ...
# 22892  Churn Prediction in Mobile Social Games: Towar...  2017
# 25782  Tracklet Association by Online Target-Specific...  2015
# 21621  An ADMM Algorithm for a Class of Total Variati...  2012
# 10371  Equitability Analysis of the Maximal Informati...  2013
# 38148  A Pointillism Approach for Natural Language Pr...  2012
#
#                                                 keywords
# 35314  [causality, typically, definition, causality, ...
# 7330   [databases, available, medicinal, representati...
# 12269  [challenge, tomography, radiation, maintaining...
# 23497  [describes, compositional, compositions, expre...
# 9945   [recordings, informative, comparative, extract...
# ...                                                  ...
# 22892  [attrition, challenge, industries, decreasing,...
# 25782  [estimation, association, optimization, framew...
# 21621  [alternating, augmented, lagrangian, optimizat...
# 10371  [dependence, equitable, relationships, differe...
# 38148  [challenges, processing, segmentation, difficu...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 35314    [causality, typically, definition, causality, ...
# 7330     [databases, available, medicinal, representati...
# 12269    [challenge, tomography, radiation, maintaining...
# 23497    [describes, compositional, compositions, expre...
# 9945     [recordings, informative, comparative, extract...
#                                ...
# 6347     [knowledge, algorithm, structure, corresponds,...
# 33098    [breakthroughs, notoriously, challenging, comp...
# 11809    [specifically, connected, convolutional, achie...
# 1136     [imitation, effective, knowledge, distillation...
# 3551     [introduces, automatic, segmentation, classifi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8738 words.
# Out of those 4545 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="14f9de1b-c1c6-4fab-b6b9-eee29d0a1b1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14f9de1b-c1c6-4fab-b6b9-eee29d0a1b1e")) {                    Plotly.newPlot(                        "14f9de1b-c1c6-4fab-b6b9-eee29d0a1b1e",                        [{"x":["responsibility","typically","structural","introduced","causality","responsible","epistemic","definition","demonstrated","incorporates","molecules","representations","extraction","hierarchical","predictive","algorithm","available","databases","unsupervised","generally","paragraph","supervised","structured","experimentally","outperforms","subgraphs","applicable","performance","benchmark","sharpness","transform","tomography","penalized","numerical","decreases","regularizer","regularization","preserving","radiation","significantly","challenge","researchers","reconstruction","maintaining","reconstructed","projection","experiments","statistical","sparsifying","difficult","determined","increases","compositions","exponential","advantage","complexity","dependence","represented","processing","decreasing","computation","describes","representation","inference","exponentially","computers","algorithms","description","compositional","expressed","particular","hierarchy","dictionary","contribute","comparing","biomedical","correlation","successfully","developed","identified","extracting","interdisciplinary","demonstrates","comparative","challenges","accurately","distribution","automatically","literature","strongest","informative","including","recordings","autocorrelation","collection","scientific","intervention","arguments","converges","formulations","generalizes","predictions","stability","formulation","generalization","connections","estimation","consistent","polynomial","conditions","establish","nonparametric","investigate","providing","scattering","intrinsic","validation","computations","extremely","consecutive","invariants","inherently","structure","localized","solutions","classification","different","statistics","discussed","computational","coefficients","extension","efficient","nonlinear","presented","nonlinearities","applicability","convolutions","artificial","deterministic","invariant","scenarios","generated","simulation","parameters","considerable","conducted","optimization","similarity","overfitting","determine","simulations","distributions","development","evaluation","expensive","generative","generator","techniques","usability","workflows","properties","experimentation","embeddings","significant","combinatorial","functions","approaches","correlations","algorithmic","byproduct","reduction","randomized","lindenstrauss","improving","concentration","multivariate","recycling","frequently","framework","attribute","traditional","interacting","interaction","conceptually","bottleneck","expressivity","application","possibilities","drawbacks","analysing","visualization","navigation","conceptual","remaining","theoretically","successful","applications","compromise","simplicity"],"y":[2,99,60,123,6,16,9,49,93,46,2,233,140,97,61,819,315,61,144,74,8,171,101,53,260,7,47,893,206,0,72,14,5,73,17,20,82,52,6,286,144,67,90,33,22,39,611,176,2,153,31,41,10,49,88,241,26,93,297,5,153,83,350,215,23,19,589,79,22,35,272,37,61,32,71,9,67,83,211,45,79,5,69,37,105,53,220,210,129,7,29,248,12,2,72,36,12,16,44,19,28,77,40,81,109,50,227,71,72,138,48,14,140,80,7,49,49,32,56,19,6,14,314,15,154,480,744,51,62,288,43,84,421,56,195,6,50,15,151,38,66,105,177,76,252,48,76,317,160,24,79,45,121,148,262,56,123,31,370,12,1,230,12,62,252,33,207,447,27,55,1,101,13,0,98,7,17,3,25,540,34,166,18,71,4,23,8,265,12,18,8,35,37,16,30,44,64,413,8,31],"type":"bar"},{"x":["responsibility","typically","structural","introduced","causal ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4545,), (4545, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8008333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unsupervised</span> <span style=''>Feature</span> <span style=''>Learning</span> <span style=''>Approach</span> <span style=''>to</span> <span style=''>Improve</span> <span style='background-color:rgba(0, 255, 0, 0.48760330578512395);'>Automatic</span> <span style=''>Incident</span> <span style='background-color:rgba(0, 255, 0, 0.574660633484163);'>Detection</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>Sophisticated</span> <span style='background-color:rgba(0, 255, 0, 0.48760330578512395);'>automatic</span> <span style=''>incident</span> <span style='background-color:rgba(0, 255, 0, 0.574660633484163);'>detection</span> <span style=''>(AID)</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>technology</span> <span style=''>plays</span> <span style=''>a</span> <span style=''>key</span> <span style=''>role</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.44444444444444453);'>contemporary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transportation</span> <span style=''>systems</span> <span style=''>Though</span> <span style=''>many</span> <span style=''>papers</span> <span style=''>were</span> <span style=''>devoted</span> <span style=''>to</span> <span style=''>study</span> <span style=''>incident</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>few</span> <span style=''>study</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigated</span> <span style=''>how</span> <span style=''>to</span> <span style=''>enhance</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.33587786259541974);'>representation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>incidents</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>AID</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>use</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>feature</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>generate</span> <span style=''>higher</span> <span style=''>level</span> <span style=''>features</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.43749999999999994);'>represent</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>incidents</span> <span style=''>We</span> <span style=''>used</span> <span style=''>real</span> <span style=''>incident</span> <span style=''>data</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>and</span> <span style=''>found</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effective</span> <span style=''>feature</span> <span style=''>mapping</span> <span style=''>function</span> <span style=''>can</span> <span style=''>be</span> <span style=''>learnt</span> <span style=''>from</span> <span style=''>the</span> <span style=''>data</span> <span style=''>crosses</span> <span style=''>the</span> <span style=''>test</span> <span style=''>sites</span> <span style=''>With</span> <span style=''>the</span> <span style=''>enhanced</span> <span style=''>features</span> <span style='background-color:rgba(0, 255, 0, 0.574660633484163);'>detection</span> <span style=''>rate</span> <span style=''>(DR)</span> <span style=''>false</span> <span style=''>alarm</span> <span style=''>rate</span> <span style=''>(FA ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Minimax</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>of</span> <span style=''>Bandable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Precision</span> <span style=''>Matrices</span> <br/><br/><span style=''>The</span> <span style=''>inverse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrix</span> <span style=''>provides</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considerable</span> <span style=''>insight</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>models</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>setting</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>is</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>normal</span> <span style=''>the</span> <span style=''>sparsity</span> <span style=''>pattern</span> <span style=''>in</span> <span style=''>the</span> <span style=''>inverse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrix</span> <span style=''>commonly</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponds</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adjacency</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Gauss</span> <span style=''>Markov</span> <span style=''>graph</span> <span style=''>which</span> <span style=''>encodes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statements</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>Minimax</span> <span style=''>results</span> <span style=''>under</span> <span style=''>the</span> <span style=''>spectral</span> <span style=''>norm</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>previously</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>established</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrices</span> <span style=''>both</span> <span style=''>sparse</span> <span style=''>and</span> <span style=''>banded</span> <span style=''>and</span> <span style=''>for</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>matrices</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>minimax</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>bounds</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>banded</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>matrices</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Dirichlet</span> <span style=''>vMF</span> <span style=''>Mixture</span> <span style=''>Model</span> <br/><br/><span style=''>This</span> <span style=''>document</span> <span style=''>is</span> <span style=''>about</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>document</span> <span style=''>Von</span> <span style=''>Mises</span> <span style=''>Fisher</span> <span style=''>mixture</span> <span style=''>model</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dirichlet</span> <span style=''>prior</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>VMFMix</span> <span style=''>VMFMix</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analogous</span> <span style=''>to</span> <span style=''>Latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Allocation</span> <span style=''>(LDA)</span> <span style=''>in</span> <span style=''>that</span> <span style=''>they</span> <span style=''>can</span> <span style=''>capture</span> <span style=''>the</span> <span style=''>co</span> <span style='background-color:rgba(0, 255, 0, 0.393939393939394);'>occurrence</span> <span style=''>patterns</span> <span style=''>acorss</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.4772727272727272);'>documents</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difference</span> <span style=''>is</span> <span style=''>that</span> <span style=''>in</span> <span style=''>VMFMix</span> <span style=''>the</span> <span style=''>topic</span> <span style=''>word</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>n</span> <span style='background-color:rgba(255, 0, 0, 0.3691756272401434);'>dimensional</span> <span style=''>hypersphere</span> <span style=''>Hence</span> <span style=''>VMFMix</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>topic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embeddings</span> <span style=''>ie</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representative</span> <span style=''>vectors</span> <span style=''>from</span> <span style=''>multiple</span> <span style=''>sets</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>vectors</span> <span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.5564516129032259);'>Variational</span> <span style='background-color:rgba(255, 0, 0, 0.3260869565217392);'>Expectation</span> <span style='background-color:rgba(255, 0, 0, 0.32);'>Maximization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>derived</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>VMFMix</span> <span style=''>on</span> <span style=''>two</span> <span style=''>document</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>tasks</span> <span style=''>is</span> <span style=''>reported</span> <span style=''>with</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>preliminary</span> <span style=''>analysis</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Empirical</span> <span style=''>Study</span> <span style=''>of</span> <span style=''>Leading</span> <span style=''>Measures</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dependence</span> <br/><br/><span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploratory</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>we</span> <span style=''>are</span> <span style=''>often</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interested</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identifying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>promising</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associations</span> <span style=''>for</span> <span style=''>further</span> <span style=''>analysis</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>filtering</span> <span style=''>out</span> <span style=''>weaker</span> <span style=''>less</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interesting</span> <span style=''>ones</span> <span style=''>This</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accomplished</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>a</span> <span style=''>measure</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>on</span> <span style=''>all</span> <span style=''>variable</span> <span style=''>pairs</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>examining</span> <span style=''>the</span> <span style=''>highest</span> <span style=''>scoring</span> <span style=''>pairs</span> <span style=''>provided</span> <span style=''>the</span> <span style=''>measure</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>used</span> <span style=''>assigns</span> <span style=''>similar</span> <span style=''>scores</span> <span style=''>to</span> <span style=''>equally</span> <span style=''>noisy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>types</span> <span style=''>This</span> <span style=''>property</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equitability</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formalized</span> <span style=''>in</span> <span style=''>Reshef</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2015b</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equitability</span> <span style=''>measures</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>can</span> <span style=''>also</span> <span style=''>be</span> <span style=''>assessed</span> <span style=''>by</span> <span style=''>the</span> <span style=''>power</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style=''>tests</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>their</span> <span style=''>runtime</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>present</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.1312410841654779)
# 	knowledge (0.12339514978601997)
# 	segmentation (0.06847360912981455)
# 	processing (0.10592011412268189)
# 	architecture (0.09236804564907275)
# 	detection (0.12410841654778887)
# 	information (0.2585592011412268)
# 	different (0.2653352353780314)
# 	convolutional (0.1340941512125535)
# 	recognition (0.13338088445078458)
#
# Some Statistics words are:
# 	theoretical (0.14428857715430862)
# 	statistical (0.1467935871743487)
# 	stochastic (0.13577154308617234)
# 	variables (0.1372745490981964)
# 	estimation (0.17685370741482967)
# 	distribution (0.17985971943887777)
# 	algorithm (0.39579158316633267)
# 	inference (0.1848697394789579)
# 	dimensional (0.19138276553106212)
# 	regression (0.18036072144288579)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d35d629d-565b-4f1f-b78e-2b619fe1514f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d35d629d-565b-4f1f-b78e-2b619fe1514f")) {                    Plotly.newPlot(                        "d35d629d-565b-4f1f-b78e-2b619fe1514f",                        [{"x":["responsibility","typically","structural","introduced","causality","responsible","epistemic","definition","demonstrated","incorporates","molecules","representations","extraction","hierarchical","predictive","algorithm","available","databases","unsupervised","generally","paragraph","supervised","structured","experimentally","outperforms","subgraphs","applicable","performance","benchmark","sharpness","transform","tomography","penalized","numerical","decreases","regularizer","regularization","preserving","radiation","significantly","challenge","researchers","reconstruction","maintaining","reconstructed","projection","experiments","statistical","sparsifying","difficult","determined","increases","compositions","exponential","advantage","complexity","dependence","represented","processing","decreasing","computation","describes","representation","inference","exponentially","computers","algorithms","description","compositional","expressed","particular","hierarchy","dictionary","contribute","comparing","biomedical","correlation","successfully","developed","identified","extracting","interdisciplinary","demonstrates","comparative","challenges","accurately","distribution","automatically","literature","strongest","informative","including","recordings","autocorrelation","collection","scientific","intervention","arguments","converges","formulations","generalizes","predictions","stability","formulation","generalization","connections","estimation","consistent","polynomial","conditions","establish","nonparametric","investigate","providing","scattering","intrinsic","validation","computations","extremely","consecutive","invariants","inherently","structure","localized","solutions","classification","different","statistics","discussed","computational","coefficients","extension","efficient","nonlinear","presented","nonlinearities","applicability","convolutions","artificial","deterministic","invariant","scenarios","generated","simulation","parameters","considerable","conducted","optimization","similarity","overfitting","determine","simulations","distributions","development","evaluation","expensive","generative","generator","techniques","usability","workflows","properties","experimentation","embeddings","significant","combinatorial","functions","approaches","correlations","algorithmic","byproduct","reduction","randomized","lindenstrauss","improving","concentration","multivariate","recycling","frequently","framework","attribute","traditional","interacting","interaction","conceptually","bottleneck","expressivity","application","possibilities","drawbacks","analysing","visualization","navigation","conceptual","remaining","theoretically","successful","applications","compromise","simplicity","visualizing","experimented","important","facilitated","cumbersome","scalability","hierarchies","interpretation","introduce","approximations","linearithmic","synthetic","covariance","symmetric","coordinates","rotations","objective","represent","represents","procedure","approximation","trajectory","approximate","correctness","efficiency","dynamical","instances","knowledge","effectiveness","regression","demonstrate","substantial","information","unfortunately","incorporate","optimisation","backpropagation","explaining","processes","discovery","phenomena","reasoning","behaviour","identification","transition","architecture","interpretable","functional","mechanisms","efficiently","induction","interpret","derivation","i ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	sharpness
# 	lindenstrauss
# 	advection
# 	possessing
# 	covariances
# 	stratification
# 	prognostics
# 	regressionclassification
# 	backfitting
# 	smoothers
# 	tibshirani
# 	unattainable
# 	parametrisation
# 	changepoints
# 	lightspeed
# 	exponents
# 	cumulants
# 	minimising
# 	phenotypes
# 	memberships
# Some words which never appear in Statistics papers:
# 	histopathology
# 	householder
# 	clickbait
# 	informations
# 	participating
# 	propositional
# 	outlining
# 	brachytherapy
# 	universality
# 	compressors
# 	compressor
# 	precursor
# 	suppressed
# 	instructive
# 	informational
# 	extractive
# 	premature
# 	indifference
# 	terascale
# 	microsoft

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.068896731624981e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7566666666666667
